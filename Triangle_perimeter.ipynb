# %% [markdown]
# <a href="https://colab.research.google.com/github/leobioinf0/nuwe_algorithms/blob/main/Triangle_perimeter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Triangle perimeter
#
# If p is the perimeter of a right angle triangle with integral length sides, {a,b,c}, there are exactly three solutions for p = 120.
#
# {20,48,52}, {24,45,51}, {30,40,50}
#
# For which value of p ≤ 1000, is the number of solutions maximised?

# %%
def get_maximised_solutions(n):
    li = []
    for p in range(1,n+1):
        if p % 2 == 0:
            l = False
            for a in range(1,p //2 +1):
                for b in range(1,p //3 +1):
                    c = p - (a+b)
                    if a**2 + b**2 == c**2:
                        l = True
            if l:
                li.append(p)
    return(li)

# %%
get_maximised_solutions(1000)
# Out:
# [12,
#  24,
#  30,
#  36,
#  40,
#  48,
#  56,
#  60,
#  70,
#  72,
#  80,
#  84,
#  90,
#  96,
#  108,
#  112,
#  120,
#  126,
#  132,
#  140,
#  144,
#  150,
#  154,
#  156,
#  160,
#  168,
#  176,
#  180,
#  182,
#  192,
#  198,
#  200,
#  204,
#  208,
#  210,
#  216,
#  220,
#  224,
#  228,
#  234,
#  240,
#  252,
#  260,
#  264,
#  270,
#  276,
#  280,
#  286,
#  288,
#  300,
#  306,
#  308,
#  312,
#  320,
#  324,
#  330,
#  336,
#  340,
#  348,
#  350,
#  352,
#  360,
#  364,
#  372,
#  374,
#  378,
#  380,
#  384,
#  390,
#  392,
#  396,
#  400,
#  408,
#  416,
#  418,
#  420,
#  432,
#  440,
#  442,
#  444,
#  448,
#  450,
#  456,
#  462,
#  468,
#  476,
#  480,
#  490,
#  492,
#  494,
#  504,
#  510,
#  516,
#  520,
#  528,
#  532,
#  540,
#  544,
#  546,
#  552,
#  560,
#  564,
#  570,
#  572,
#  576,
#  588,
#  594,
#  598,
#  600,
#  608,
#  612,
#  616,
#  624,
#  630,
#  636,
#  640,
#  644,
#  646,
#  648,
#  650,
#  660,
#  672,
#  680,
#  684,
#  690,
#  696,
# ...
